# %%
# Import everything needed
import numpy as np
import matplotlib.pyplot as plt
import string
import random



labels = list(string.ascii_uppercase)

def plot_locations_and_edges(locations, distance, order_label):
    n = len(order_label)
    labels_order = [order_label.index(labels[i]) for i in range(n)]
    
    order = [labels.index(order_label[i]) for i in range(n)]
    
    #print(order)
    x,y = np.transpose(locations);
    for i in range(n):
        plt.annotate(labels_order[i], [x[i]+2, y[i]])
        plt.annotate(labels[i], [x[i], y[i]])
    for i in range(n-1):
        #plt.arrow(locations[i,0],locations[i,1],locations[i+1,0]-locations[i,0],locations[i+1,1]-locations[i,1], head_width=2, head_length=4, fc='blue',  color = "blue")
        plt.plot([locations[order[i],0], locations[order[i+1],0]], [locations[order[i],1], locations[order[i+1],1]], color = "blue", linestyle = "solid", linewidth= 1)
    plt.plot([locations[order[0],0], locations[order[n-1],0]], [locations[order[0],1], locations[order[n-1],1]], color = "blue", linestyle = "solid", linewidth= 1)
    
    
    

    #plt.scatter(x,y, color = "red");
#     plt.xlim(-5,105)
#     plt.ylim(-5,105)
    plt.xlabel("x-coordinate")
    plt.ylabel("y-coordinate")
    plt.title("TSP Solution: Score = " + str(score(order, distance)))
    plt.show()


def dist(u,v):
    return np.sqrt((u[0] - v[0])**2 + (u[1] - v[1])**2)

def score(order, distance):
    return sum([distance[order[i],order[i+1]] for i in range(len(order)-1)]) + distance[order[0],order[len(order)-1]]


# Random instances:
def rand_locations(n):
    locations  = np.random.randint(100, size=(n, 2))
    distances = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            distances[i,j] = dist(locations[i], locations[j])
        
    return locations, distances

def initial_order(n):
    order = list(range(n))
    return [labels[i] for i in order]

def reversal(order, i,j):
    temp_order = order.copy()
    temp_order[i:j+1]= temp_order[i:j+1][::-1]
    return temp_order

def reversal_plot(locations, distance, order_label, I,J):
    n = len(order_label)
    n = len(order_label)
    order = [labels.index(order_label[i]) for i in range(n)]
    labels_order = [order_label.index(labels[i]) for i in range(n)]
    
    order_new = reversal(order, I,J)

    
    #print(order)
    x,y = np.transpose(locations);
    for i in range(n):
        plt.annotate(labels_order[i], [x[i]+2, y[i]])
        plt.annotate(labels[i], [x[i], y[i]])
    plt.xlabel("x-coordinate")
    plt.ylabel("y-coordinate")
    
    
    
    for i in range(n-1):
        #plt.arrow(locations[i,0],locations[i,1],locations[i+1,0]-locations[i,0],locations[i+1,1]-locations[i,1], head_width=2, head_length=4, fc='blue',  color = "blue")
        plt.plot([locations[order_new[i],0], locations[order_new[i+1],0]], [locations[order_new[i],1], locations[order_new[i+1],1]], color = "blue", linestyle = "solid", linewidth= 1)
    plt.plot([locations[order_new[0],0], locations[order_new[n-1],0]], [locations[order_new[0],1], locations[order_new[n-1],1]], color = "blue", linestyle = "solid", linewidth= 1)
    
    
    for i in [I-1,J]:
        i1 = i; i2 = i+1;
        if i2 == n:
            i2 = 0
        #plt.arrow(locations[i,0],locations[i,1],locations[i+1,0]-locations[i,0],locations[i+1,1]-locations[i,1], head_width=2, head_length=4, fc='blue',  color = "blue")
        plt.plot([locations[order[i1],0], locations[order[i2],0]], [locations[order[i1],1], locations[order[i2],1]], color = "red", linestyle = "solid", linewidth= 2)
        plt.plot([locations[order_new[i1],0], locations[order_new[i2],0]], [locations[order_new[i1],1], locations[order_new[i2],1]], color = "green", linestyle = "solid", linewidth= 2)
   
    
#     for e in [e1,e2]:
#         plt.plot([locations[e[0],0], locations[e[1],0]], [locations[e[0],1], locations[e[1],1]], color = "red", linestyle = "solid", linewidth= 2)
#     plt.plot([locations[e1[0],0], locations[e2[0],0]], [locations[e1[0],1], locations[e2[0],1]], color = "green", linestyle = "solid", linewidth= 2)
#     plt.plot([locations[e2[1],0], locations[e1[1],0]], [locations[e2[1],1], locations[e1[1],1]], color = "green", linestyle = "solid", linewidth= 2)
    
    
#     index_max = max([max([order.index(e[0]), order.index(e[1])]) for e in [e1,e2]])
#     index_min = min([min([order.index(e[0]), order.index(e[1])]) for e in [e1,e2]])
#     #print([index_max, index_min])
#     if a == 0:
#         index_max = n
#         index_min = min([order.index(e2[0]), order.index(e2[1])])
#     if b == 0:
#         index_max = n
#         index_min = min([order.index(e1[0]), order.index(e1[1])])
        
#     #print([index_max, index_min])
#     order = reversal(order, index_min+1, index_max)
    #print([index_min, index_max])
    #print(order)
    plt.title("TSP Solution: Score = " + str(score(order_new, distance)))
    plt.show()
    print(I,J, [labels[i] for i in order_new])
    return [labels[i] for i in order_new]

def reversal_list(locations, distance, order_label):
    n = len(order_label)
    order = [labels.index(order_label[i]) for i in range(n)]
    labels_order = [order_label.index(labels[i]) for i in range(n)]
    
    for i in range(1,n-1):
        for j in range(i+1,n):
            order_temp = reversal(order, i, j)
            print(i,j, [labels[i] for i in order_temp])
            print("Reversal: "+ str(i) + str(j) + ", Score: " + str(score(order_temp, distance)))

def reversal_score(locations, distance, order_label, i,j):
    n = len(order_label)
    order = [labels.index(order_label[i]) for i in range(n)]
    labels_order = [order_label.index(labels[i]) for i in range(n)]
    order_temp = reversal(order, i, j)
    print(i,j, [labels[i] for i in order_temp])
    print("Reversal: "+ str(i) + str(j) + ", Score: " + str(score(order_temp, distance)))
            
            
locations = np.array([[88, 79],
       [78, 10],
       [89, 73],
       [86,  1],
       [75, 61],
       [50, 47],
       [30, 23],
       [11, 40],
       [40,  8],
       [ 2, 17],
       [62, 45],
       [42, 97],
       [65, 31]])
distance = np.array([[  0.        ,  69.72087205,   6.08276253,  78.02563681,
         22.20360331,  49.67896939,  80.62257748,  86.31338251,
         85.70297544, 106.01886625,  42.80186912,  49.39635614,
         53.22593353],
       [ 69.72087205,   0.        ,  63.95310782,  12.04159458,
         51.0881591 ,  46.40043103,  49.72926704,  73.40980861,
         38.05259518,  76.32168761,  38.48376281,  94.15412896,
         24.69817807],
       [  6.08276253,  63.95310782,   0.        ,  72.0624729 ,
         18.43908891,  46.87216658,  77.3369252 ,  84.69356528,
         81.4002457 , 103.46496992,  38.89730068,  52.77309921,
         48.37354649],
       [ 78.02563681,  12.04159458,  72.0624729 ,   0.        ,
         61.        ,  58.41232747,  60.16643583,  84.53401682,
         46.5295605 ,  85.51023331,  50.11985634, 105.60303026,
         36.61966685],
       [ 22.20360331,  51.0881591 ,  18.43908891,  61.        ,
          0.        ,  28.65309756,  58.89821729,  67.35725648,
         63.51377803,  85.23496935,  20.61552813,  48.83646179,
         31.6227766 ],
       [ 49.67896939,  46.40043103,  46.87216658,  58.41232747,
         28.65309756,   0.        ,  31.2409987 ,  39.62322551,
         40.26164428,  56.60388679,  12.16552506,  50.6359556 ,
         21.9317122 ],
       [ 80.62257748,  49.72926704,  77.3369252 ,  60.16643583,
         58.89821729,  31.2409987 ,   0.        ,  25.49509757,
         18.02775638,  28.63564213,  38.83297568,  74.96665926,
         35.90264614],
       [ 86.31338251,  73.40980861,  84.69356528,  84.53401682,
         67.35725648,  39.62322551,  25.49509757,   0.        ,
         43.18564576,  24.69817807,  51.2445119 ,  64.88451279,
         54.74486277],
       [ 85.70297544,  38.05259518,  81.4002457 ,  46.5295605 ,
         63.51377803,  40.26164428,  18.02775638,  43.18564576,
          0.        ,  39.05124838,  43.0464865 ,  89.02246907,
         33.9705755 ],
       [106.01886625,  76.32168761, 103.46496992,  85.51023331,
         85.23496935,  56.60388679,  28.63564213,  24.69817807,
         39.05124838,   0.        ,  66.21178143,  89.4427191 ,
         64.5368112 ],
       [ 42.80186912,  38.48376281,  38.89730068,  50.11985634,
         20.61552813,  12.16552506,  38.83297568,  51.2445119 ,
         43.0464865 ,  66.21178143,   0.        ,  55.71355311,
         14.31782106],
       [ 49.39635614,  94.15412896,  52.77309921, 105.60303026,
         48.83646179,  50.6359556 ,  74.96665926,  64.88451279,
         89.02246907,  89.4427191 ,  55.71355311,   0.        ,
         69.89277502],
       [ 53.22593353,  24.69817807,  48.37354649,  36.61966685,
         31.6227766 ,  21.9317122 ,  35.90264614,  54.74486277,
         33.9705755 ,  64.5368112 ,  14.31782106,  69.89277502,
          0.        ]])

# %%
initial_order(13)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

# %%
n = 13

order = initial_order(n)
order
plot_locations_and_edges(locations, distance, order)
order
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

# %%
current_order = ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']

reversal_list(locations, distance, current_order)
# Out:
# 1 2 ['A', 'D', 'C', 'E', 'F', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 12, Score: 646.0860290500001
# 1 3 ['A', 'E', 'D', 'C', 'F', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 13, Score: 651.0439756600001
# 1 4 ['A', 'F', 'E', 'D', 'C', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 14, Score: 677.8529495100001
# 1 5 ['A', 'B', 'F', 'E', 'D', 'C', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 15, Score: 707.9498335400001
# 1 6 ['A', 'G', 'B', 'F', 'E', 'D', 'C', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 16, Score: 750.4423485200001
# 1 7 ['A', 'H', 'G', 'B', 'F', 'E', 'D', 'C', 'I', 'J', 'K', 'L', 'M']
# Reversal: 17, Score: 735.1492857800001
# 1 8 ['A', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'C', 'J', 'K', 'L', 'M']
# Reversal: 18, Score: 760.7380003100001
# 1 9 ['A', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'C', 'K', 'L', 'M']
# Reversal: 19, Score: 689.3256888300001
# 1 10 ['A', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'C', 'L', 'M']
# Reversal: 110, Score: 650.4827185500001
# 1 11 ['A', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'C', 'M']
# Reversal: 111, Score: 638.49843094
# 1 12 ['A', 'M', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'C']
# Reversal: 112, Score: 616.7040658599999
# 2 3 ['A', 'C', 'E', 'D', 'F', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 23, Score: 592.8399117800001
# 2 4 ['A', 'C', 'F', 'E', 'D', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 24, Score: 557.15492309
# 2 5 ['A', 'C', 'B', 'F', 'E', 'D', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 25, Score: 619.03186957
# 2 6 ['A', 'C', 'G', 'B', 'F', 'E', 'D', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 26, Score: 681.0174374100001
# 2 7 ['A', 'C', 'H', 'G', 'B', 'F', 'E', 'D', 'I', 'J', 'K', 'L', 'M']
# Reversal: 27, Score: 632.6790729800001
# 2 8 ['A', 'C', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'J', 'K', 'L', 'M']
# Reversal: 28, Score: 672.5008235900001
# 2 9 ['A', 'C', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'K', 'L', 'M']
# Reversal: 29, Score: 632.01463779
# 2 10 ['A', 'C', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'L', 'M']
# Reversal: 210, Score: 633.42837079
# 2 11 ['A', 'C', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D', 'M']
# Reversal: 211, Score: 564.141584
# 2 12 ['A', 'C', 'M', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'D']
# Reversal: 212, Score: 617.81484273
# 3 4 ['A', 'C', 'D', 'F', 'E', 'B', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 34, Score: 618.8041214000001
# 3 5 ['A', 'C', 'D', 'B', 'F', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 35, Score: 576.91461069
# 3 6 ['A', 'C', 'D', 'G', 'B', 'F', 'E', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 36, Score: 657.7326606
# 3 7 ['A', 'C', 'D', 'H', 'G', 'B', 'F', 'E', 'I', 'J', 'K', 'L', 'M']
# Reversal: 37, Score: 660.5662149500001
# 3 8 ['A', 'C', 'D', 'I', 'H', 'G', 'B', 'F', 'E', 'J', 'K', 'L', 'M']
# Reversal: 38, Score: 648.4173473300001
# 3 9 ['A', 'C', 'D', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'K', 'L', 'M']
# Reversal: 39, Score: 595.6180458700001
# 3 10 ['A', 'C', 'D', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'L', 'M']
# Reversal: 310, Score: 598.94683088
# 3 11 ['A', 'C', 'D', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E', 'M']
# Reversal: 311, Score: 623.0370977
# 3 12 ['A', 'C', 'D', 'M', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'E']
# Reversal: 312, Score: 561.30140249
# 4 5 ['A', 'C', 'D', 'E', 'B', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 45, Score: 620.65085906
# 4 6 ['A', 'C', 'D', 'E', 'G', 'B', 'F', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 46, Score: 661.0773135300001
# 4 7 ['A', 'C', 'D', 'E', 'H', 'G', 'B', 'F', 'I', 'J', 'K', 'L', 'M']
# Reversal: 47, Score: 652.4842233
# 4 8 ['A', 'C', 'D', 'E', 'I', 'H', 'G', 'B', 'F', 'J', 'K', 'L', 'M']
# Reversal: 48, Score: 669.1173847400001
# 4 9 ['A', 'C', 'D', 'E', 'J', 'I', 'H', 'G', 'B', 'F', 'K', 'L', 'M']
# Reversal: 49, Score: 619.23968128
# 4 10 ['A', 'C', 'D', 'E', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'L', 'M']
# Reversal: 410, Score: 603.58889892
# 4 11 ['A', 'C', 'D', 'E', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F', 'M']
# Reversal: 411, Score: 588.92636727
# 4 12 ['A', 'C', 'D', 'E', 'M', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'F']
# Reversal: 412, Score: 616.1267807600001
# 5 6 ['A', 'C', 'D', 'E', 'F', 'G', 'B', 'H', 'I', 'J', 'K', 'L', 'M']
# Reversal: 56, Score: 649.4593445700001
# 5 7 ['A', 'C', 'D', 'E', 'F', 'H', 'G', 'B', 'I', 'J', 'K', 'L', 'M']
# Reversal: 57, Score: 604.7938097600002
# 5 8 ['A', 'C', 'D', 'E', 'F', 'I', 'H', 'G', 'B', 'J', 'K', 'L', 'M']
# Reversal: 58, Score: 647.8357183400001
# 5 9 ['A', 'C', 'D', 'E', 'F', 'J', 'I', 'H', 'G', 'B', 'K', 'L', 'M']
# Reversal: 59, Score: 599.1795030000001
# 5 10 ['A', 'C', 'D', 'E', 'F', 'K', 'J', 'I', 'H', 'G', 'B', 'L', 'M']
# Reversal: 510, Score: 620.90973574
# 5 11 ['A', 'C', 'D', 'E', 'F', 'L', 'K', 'J', 'I', 'H', 'G', 'B', 'M']
# Reversal: 511, Score: 575.7449934800001
# 5 12 ['A', 'C', 'D', 'E', 'F', 'M', 'L', 'K', 'J', 'I', 'H', 'G', 'B']
# Reversal: 512, Score: 608.73028555
# 6 7 ['A', 'C', 'D', 'E', 'F', 'B', 'H', 'G', 'I', 'J', 'K', 'L', 'M']
# Reversal: 67, Score: 615.2267180500002
# 6 8 ['A', 'C', 'D', 'E', 'F', 'B', 'I', 'H', 'G', 'J', 'K', 'L', 'M']
# Reversal: 68, Score: 594.6117877500001
# 6 9 ['A', 'C', 'D', 'E', 'F', 'B', 'J', 'I', 'H', 'G', 'K', 'L', 'M']
# Reversal: 69, Score: 615.9176806800001
# 6 10 ['A', 'C', 'D', 'E', 'F', 'B', 'K', 'J', 'I', 'H', 'G', 'L', 'M']
# Reversal: 610, Score: 624.7116677800001
# 6 11 ['A', 'C', 'D', 'E', 'F', 'B', 'L', 'K', 'J', 'I', 'H', 'G', 'M']
# Reversal: 611, Score: 627.1387989
# 6 12 ['A', 'C', 'D', 'E', 'F', 'B', 'M', 'L', 'K', 'J', 'I', 'H', 'G']
# Reversal: 612, Score: 619.0696208400001
# 7 8 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'I', 'H', 'J', 'K', 'L', 'M']
# Reversal: 78, Score: 594.88365436
# 7 9 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'J', 'I', 'H', 'K', 'L', 'M']
# Reversal: 79, Score: 604.8773408900001
# 7 10 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'K', 'J', 'I', 'H', 'L', 'M']
# Reversal: 710, Score: 639.2129036500002
# 7 11 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'L', 'K', 'J', 'I', 'H', 'M']
# Reversal: 711, Score: 651.0277153
# 7 12 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'M', 'L', 'K', 'J', 'I', 'H']
# Reversal: 712, Score: 660.1990634099999
# 8 9 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'J', 'I', 'K', 'L', 'M']
# Reversal: 89, Score: 575.05130324
# 8 10 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'K', 'J', 'I', 'L', 'M']
# Reversal: 810, Score: 658.0718479600001
# 8 11 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'L', 'K', 'J', 'I', 'M']
# Reversal: 811, Score: 602.4807333699999
# 8 12 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'M', 'L', 'K', 'J', 'I']
# Reversal: 812, Score: 660.74032478
# 9 10 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'K', 'J', 'L', 'M']
# Reversal: 910, Score: 654.42846997
# 9 11 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'L', 'K', 'J', 'M']
# Reversal: 911, Score: 661.3193227300001
# 9 12 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'M', 'L', 'K', 'J']
# Reversal: 912, Score: 664.4163257
# 10 11 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'J', 'L', 'K', 'M']
# Reversal: 1011, Score: 584.3600495700001
# 10 12 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'J', 'M', 'L', 'K']
# Reversal: 1012, Score: 604.60503122
# 11 12 ['A', 'C', 'D', 'E', 'F', 'B', 'G', 'H', 'I', 'J', 'K', 'M', 'L']
# Reversal: 1112, Score: 571.4787564200001

# %%
## 
Z_c = 679.40
Z_n = 555.74
T = 1000
### If Z_n < Z_c, accept the move and execute the command:
##  order = reversal_plot(locations, distance, order, i,j)

## Otherwise, accept the move with probability exp((Z_c - Z_n)/T)
random_num = random.uniform(0, 1)
print("Random Number: ", random_num)

probability_of_acceptance = np.exp((Z_c - Z_n)/T)

print("Probability to Accept: ", probability_of_acceptance)

print(random_num < probability_of_acceptance)
# Out:
# Random Number:  0.005884690953071425
# Probability to Accept:  1.1316310510261378
# True

# %%
# order = reversal_plot(locations, distance, order, 2,5)
